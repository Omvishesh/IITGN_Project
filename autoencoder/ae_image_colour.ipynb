# %%
from tensorflow.keras.layers import Conv2D, UpSampling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
from skimage.color import rgb2lab, lab2rgb
from skimage.transform import resize
from skimage.io import imsave
import numpy as np
import tensorflow as tf

# %%
path = 'E:\\IITGN_Project\\autoencoder\\data\\faces\\'

# %%
train_datagen = ImageDataGenerator(rescale=1. / 255)


import os
from PIL import Image

faces_path = 'E:\\IITGN_Project\\autoencoder\\data\\faces\\'
images = []
for img_file in os.listdir(faces_path):
    if img_file.lower().endswith(('.jpg', '.jpeg', '.png')):
        img = load_img(os.path.join(faces_path, img_file), target_size=(256, 256))
        img_array = img_to_array(img) / 255.0 
        images.append(img_array)

train = [np.array(images)]  
print(f"Loaded {len(images)} images")
# Out:
# Loaded 150 images

# %% [markdown]
# ##### by iterating on each image, we convert the RGB to Lab. Think of LAB image as a grey image in L channel and all color info stored in A and B channels. The input to the network will be the L channel, so we assign L channel to X vector. And assign A and B to Y.

# %%
X =[]
Y =[]
for img in train[0]:
  try:
      lab = rgb2lab(img)
      X.append(lab[:,:,0]) 
      Y.append(lab[:,:,1:] / 128) #A and B values range from -127 to 128, 
      #so we divide the values by 128 to restrict values to between -1 and 1.
  except:
     print('error')
X = np.array(X)
Y = np.array(Y)
X = X.reshape(X.shape+(1,)) #dimensions to be the same for X and Y
print(X.shape)
print(Y.shape)
# Out:
# (150, 256, 256, 1)
# (150, 256, 256, 2)

# %%
model = Sequential()
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', strides=2, input_shape=(256, 256, 1)))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(128, (3,3), activation='relu', padding='same', strides=2))
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(Conv2D(256, (3,3), activation='relu', padding='same', strides=2))
model.add(Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))

model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3,3), activation='relu', padding='same'))
model.add(Conv2D(16, (3,3), activation='relu', padding='same'))
model.add(Conv2D(2, (3, 3), activation='tanh', padding='same'))
model.add(UpSampling2D((2, 2)))
model.compile(optimizer='adam', loss='mse' , metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_39 (Conv2D)              │ (None, 128, 128, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_40 (Conv2D)              │ (None, 128, 128, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_41 (Conv2D)              │ (None, 64, 64, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_42 (Conv2D)              │ (None, 64, 64, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_43 (Conv2D)              │ (None, 32, 32, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_44 (Conv2D)              │ (None, 32, 32, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_45 (Conv2D)              │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_46 (Conv2D)              │ (None, 32, 32, 256)    │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_47 (Conv2D)              │ (None, 32, 32, 128)    │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_9 (UpSampling2D)  │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_48 (Conv2D)              │ (None, 64, 64, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_10 (UpSampling2D) │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_49 (Conv2D)              │ (None, 128, 128, 32)   │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_50 (Conv2D)              │ (None, 128, 128, 16)   │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_51 (Conv2D)              │ (None, 128, 128, 2)    │           290 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_11 (UpSampling2D) │ (None, 256, 256, 2)    │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,219,410 (23.73 MB)
#  Trainable params: 6,219,410 (23.73 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau


callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
]


model.fit(X, Y, 
          validation_split=0.1, 
          epochs=50, 
          batch_size=4,  
          callbacks=callbacks,
          verbose=1)

model.save('colorize_autoencoder.keras')
# Out:
# Epoch 1/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.4996 - loss: 0.0061 - val_accuracy: 0.6098 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 2/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.6017 - loss: 0.0076 - val_accuracy: 0.5955 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 3/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 33s 984ms/step - accuracy: 0.5764 - loss: 0.0074 - val_accuracy: 0.5654 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 4/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 33s 947ms/step - accuracy: 0.5789 - loss: 0.0066 - val_accuracy: 0.5626 - val_loss: 0.0057 - learning_rate: 0.0010
# Epoch 5/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 31s 910ms/step - accuracy: 0.5319 - loss: 0.0066 - val_accuracy: 0.5597 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 6/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.5905 - loss: 0.0063 - val_accuracy: 0.5618 - val_loss: 0.0045 - learning_rate: 0.0010
# Epoch 7/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 32s 937ms/step - accuracy: 0.5831 - loss: 0.0066 - val_accuracy: 0.5671 - val_loss: 0.0045 - learning_rate: 0.0010
# Epoch 8/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 33s 977ms/step - accuracy: 0.6091 - loss: 0.0062 - val_accuracy: 0.5842 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 9/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 33s 985ms/step - accuracy: 0.6075 - loss: 0.0067 - val_accuracy: 0.6288 - val_loss: 0.0044 - learning_rate: 0.0010
# Epoch 10/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.6185 - loss: 0.0068 - val_accuracy: 0.5935 - val_loss: 0.0044 - learning_rate: 0.0010
# Epoch 11/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.5881 - loss: 0.0071 - val_accuracy: 0.6078 - val_loss: 0.0045 - learning_rate: 0.0010
# Epoch 12/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.5545 - loss: 0.0071 - val_accuracy: 0.6209 - val_loss: 0.0044 - learning_rate: 0.0010
# Epoch 13/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.6416 - loss: 0.0058 - val_accuracy: 0.5330 - val_loss: 0.0044 - learning_rate: 0.0010
# Epoch 14/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.5777 - loss: 0.0061 - val_accuracy: 0.5993 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 15/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 32s 952ms/step - accuracy: 0.6269 - loss: 0.0054 - val_accuracy: 0.6250 - val_loss: 0.0045 - learning_rate: 5.0000e-04
# Epoch 16/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 32s 954ms/step - accuracy: 0.6337 - loss: 0.0057 - val_accuracy: 0.6273 - val_loss: 0.0044 - learning_rate: 5.0000e-04
# Epoch 17/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 30s 887ms/step - accuracy: 0.6460 - loss: 0.0053 - val_accuracy: 0.6204 - val_loss: 0.0042 - learning_rate: 5.0000e-04
# Epoch 18/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 32s 938ms/step - accuracy: 0.6272 - loss: 0.0063 - val_accuracy: 0.6223 - val_loss: 0.0044 - learning_rate: 5.0000e-04
# Epoch 19/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.6474 - loss: 0.0043 - val_accuracy: 0.6360 - val_loss: 0.0045 - learning_rate: 5.0000e-04
# Epoch 20/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.6541 - loss: 0.0060 - val_accuracy: 0.6181 - val_loss: 0.0041 - learning_rate: 5.0000e-04
# Epoch 21/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.6549 - loss: 0.0061 - val_accuracy: 0.6159 - val_loss: 0.0040 - learning_rate: 5.0000e-04
# Epoch 22/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.6380 - loss: 0.0048 - val_accuracy: 0.6035 - val_loss: 0.0042 - learning_rate: 5.0000e-04
# Epoch 23/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.6450 - loss: 0.0054 - val_accuracy: 0.6123 - val_loss: 0.0044 - learning_rate: 5.0000e-04
# Epoch 24/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.6443 - loss: 0.0054 - val_accuracy: 0.6234 - val_loss: 0.0043 - learning_rate: 5.0000e-04
# Epoch 25/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.6617 - loss: 0.0045 - val_accuracy: 0.6137 - val_loss: 0.0044 - learning_rate: 5.0000e-04
# Epoch 26/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.6602 - loss: 0.0065 - val_accuracy: 0.6380 - val_loss: 0.0038 - learning_rate: 5.0000e-04
# Epoch 27/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.6529 - loss: 0.0044 - val_accuracy: 0.6251 - val_loss: 0.0042 - learning_rate: 5.0000e-04
# Epoch 28/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 33s 968ms/step - accuracy: 0.6354 - loss: 0.0041 - val_accuracy: 0.6217 - val_loss: 0.0040 - learning_rate: 5.0000e-04
# Epoch 29/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.6543 - loss: 0.0051 - val_accuracy: 0.6242 - val_loss: 0.0044 - learning_rate: 5.0000e-04
# Epoch 30/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.6529 - loss: 0.0061 - val_accuracy: 0.6215 - val_loss: 0.0038 - learning_rate: 5.0000e-04
# Epoch 31/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 33s 971ms/step - accuracy: 0.6763 - loss: 0.0048 - val_accuracy: 0.6430 - val_loss: 0.0036 - learning_rate: 5.0000e-04
# Epoch 32/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.6736 - loss: 0.0033 - val_accuracy: 0.6209 - val_loss: 0.0041 - learning_rate: 5.0000e-04
# Epoch 33/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.6661 - loss: 0.0043 - val_accuracy: 0.6249 - val_loss: 0.0034 - learning_rate: 5.0000e-04
# Epoch 34/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.6614 - loss: 0.0055 - val_accuracy: 0.6204 - val_loss: 0.0040 - learning_rate: 5.0000e-04
# Epoch 35/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.7001 - loss: 0.0042 - val_accuracy: 0.6391 - val_loss: 0.0035 - learning_rate: 5.0000e-04
# Epoch 36/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 33s 957ms/step - accuracy: 0.6879 - loss: 0.0037 - val_accuracy: 0.6350 - val_loss: 0.0035 - learning_rate: 5.0000e-04
# Epoch 37/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.7033 - loss: 0.0046 - val_accuracy: 0.6271 - val_loss: 0.0036 - learning_rate: 5.0000e-04
# Epoch 38/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.6697 - loss: 0.0037 - val_accuracy: 0.6339 - val_loss: 0.0034 - learning_rate: 5.0000e-04
# Epoch 39/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.6774 - loss: 0.0031 - val_accuracy: 0.6395 - val_loss: 0.0033 - learning_rate: 2.5000e-04
# Epoch 40/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.6844 - loss: 0.0037 - val_accuracy: 0.6183 - val_loss: 0.0030 - learning_rate: 2.5000e-04
# Epoch 41/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 33s 976ms/step - accuracy: 0.6980 - loss: 0.0032 - val_accuracy: 0.6404 - val_loss: 0.0034 - learning_rate: 2.5000e-04
# Epoch 42/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.7075 - loss: 0.0031 - val_accuracy: 0.6361 - val_loss: 0.0030 - learning_rate: 2.5000e-04
# Epoch 43/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.6887 - loss: 0.0028 - val_accuracy: 0.6390 - val_loss: 0.0031 - learning_rate: 2.5000e-04
# Epoch 44/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.7078 - loss: 0.0027 - val_accuracy: 0.6330 - val_loss: 0.0030 - learning_rate: 2.5000e-04
# Epoch 45/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.6910 - loss: 0.0032 - val_accuracy: 0.6341 - val_loss: 0.0032 - learning_rate: 2.5000e-04
# Epoch 46/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.7161 - loss: 0.0026 - val_accuracy: 0.6309 - val_loss: 0.0029 - learning_rate: 1.2500e-04
# Epoch 47/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.7239 - loss: 0.0033 - val_accuracy: 0.6377 - val_loss: 0.0028 - learning_rate: 1.2500e-04
# Epoch 48/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.7253 - loss: 0.0026 - val_accuracy: 0.6377 - val_loss: 0.0029 - learning_rate: 1.2500e-04
# Epoch 49/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.7311 - loss: 0.0027 - val_accuracy: 0.6341 - val_loss: 0.0027 - learning_rate: 1.2500e-04
# Epoch 50/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.7230 - loss: 0.0026 - val_accuracy: 0.6463 - val_loss: 0.0030 - learning_rate: 1.2500e-04

# %%
tf.keras.models.load_model(
    r'E:\IITGN_Project\autoencoder\colorize_autoencoder.keras',
    custom_objects=None,
    compile=True)
# Out:
# <Sequential name=sequential_3, built=True>

# %%
img1_color=[]

# %%
img1=img_to_array(load_img(r'E:\IITGN_Project\autoencoder\1 (6).jpg'))
img1 = resize(img1 ,(256,256))
img1_color.append(img1)
img1_color = np.array(img1_color, dtype=float)
img1_color = rgb2lab(1.0/255*img1_color)[:,:,:,0]
img1_color = img1_color.reshape(img1_color.shape+(1,))

# %%
output1 = model.predict(img1_color)
output1 = output1*128


result = np.zeros((256, 256, 3), dtype=float)
result[:,:,0] = img1_color[0][:,:,0] 
result[:,:,1:] = output1[0] 


result[:,:,0] = np.clip(result[:,:,0], 0, 100) 
result[:,:,1:] = np.clip(result[:,:,1:], -127, 127) 

rgb_result = lab2rgb(result)
rgb_result = (rgb_result * 255).astype(np.uint8)  #

from PIL import Image as PILImage
PILImage.fromarray(rgb_result).save("result.png")
print("Image saved as result.png")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# Image saved as result.png
